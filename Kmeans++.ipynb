# %% [markdown]
# # K means++
# - K means is quite sensitive to initialistaion, if the init is not good, our algorithm will not able to make desired number of clusters.
# - To overcome this Problem , we use this technique called K means++ which choses initial centres so that they are statistically closed to final ones .
# - The method is default choice for sklearn, so we will use it directly without going into too much maths.!
# ​

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X,Y=make_blobs(n_samples=500,n_features=2, centers=5,random_state=3)

# %%
from sklearn.cluster import KMeans

# %%
Kmeans=KMeans(n_clusters=5)

# %%
Kmeans.fit(X,Y)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
centres=Kmeans.cluster_centers_

# %% [markdown]
# # Visualisation

# %%
plt.scatter(X[:,0],X[:,1],c=pred)
plt.scatter(centres[:,0],centres[:,1],marker='*',color='black')
plt.title('Prediction')
plt.grid('True')
plt.show()

# %%
pred=Kmeans.labels_
print(pred)
# Out:
# [4 1 2 4 4 2 0 4 1 4 1 2 1 4 2 4 1 4 4 1 3 3 4 2 4 3 0 0 2 0 4 0 3 3 4 3 1
#  1 4 3 3 3 0 0 2 1 1 0 0 0 1 4 0 4 4 3 4 4 1 2 1 2 2 4 0 1 2 2 3 2 3 4 3 4
#  3 2 4 0 3 3 2 3 2 0 1 0 2 1 0 2 0 3 4 3 3 1 4 2 2 3 1 3 2 2 1 1 1 2 2 4 1
#  0 4 1 2 3 1 0 3 2 1 2 0 4 3 0 0 0 4 4 2 2 4 1 1 0 2 0 2 4 4 3 2 1 0 4 1 1
#  4 2 4 4 2 2 1 3 3 0 2 4 3 1 0 3 1 3 1 3 3 3 0 4 3 1 3 0 4 2 1 0 1 4 1 3 0
#  0 3 4 2 1 3 2 0 4 0 3 2 0 4 4 4 3 3 1 4 0 0 4 1 4 4 4 3 1 2 1 4 4 1 0 2 0
#  0 3 4 2 4 2 0 3 2 2 4 3 4 3 2 1 2 3 3 1 4 4 2 2 3 1 3 4 0 1 0 4 0 0 0 0 1
#  3 1 4 3 1 0 2 1 1 1 0 4 4 2 3 3 1 2 2 4 2 0 2 1 1 0 0 3 0 0 1 3 4 2 3 2 0
#  2 2 1 4 3 1 3 3 4 0 3 2 3 0 4 4 2 1 3 0 1 3 2 0 1 0 4 3 0 2 2 3 3 3 4 0 3
#  4 1 2 2 0 1 1 2 2 0 3 3 3 4 0 1 0 4 3 1 1 2 3 3 0 3 0 2 2 2 0 3 4 3 2 0 0
#  1 4 1 0 4 0 2 1 3 1 2 4 4 1 1 3 1 3 0 2 1 0 4 4 1 2 3 0 4 4 4 0 1 3 1 1 1
#  0 3 2 1 2 2 0 2 4 2 4 1 3 3 4 1 0 4 3 2 1 0 2 0 0 1 0 2 0 1 0 2 0 4 3 3 0
#  3 1 3 3 0 4 4 2 0 3 2 0 2 1 2 1 4 3 2 4 2 4 4 3 4 3 0 1 1 2 4 4 0 0 1 0 0
#  1 0 1 1 1 0 3 0 2 1 2 2 0 2 0 3 3 0 1]

# %%
# so for each training point it is giving one cluster

# %%
print(pred.shape)
# Out:
# (500,)

# %%
plt.scatter(X[:,0],X[:,1],c=Y)
#plt.scatter(centres[:,0],centres[:,1],marker='*',color='black')
plt.title('Actual')
plt.grid('True')
plt.show()
